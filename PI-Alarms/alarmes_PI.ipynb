# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\ersantos\Desktop\Atalhos\Desktop\Python\trabalho\AlarmesPI\Base\alarmesPI.xlsx")

# %%
df
# Out:
#                                     Event name           Start time  \
# 0         Tempo_Parado 2024-01-09 10:00:00.000  2024-01-09 10:00:00
# 1                Baixo 2024-01-10 09:15:42.000  2024-01-10 09:15:42
# 2    Qualidade_Amarelo 2024-01-10 09:31:49.000  2024-01-10 09:31:49
# 3          Notificação 2024-01-10 11:11:00.000  2024-01-10 11:11:00
# 4              Medicao 2024-01-10 11:30:34.000  2024-01-10 11:30:34
# ..                                         ...                  ...
# 193       Sirene_Ativa 2024-01-04 18:17:25.000         45295.762095
# 194          Analysis1 2024-01-05 06:30:00.000         45296.270833
# 195          Analysis1 2024-01-05 08:01:00.000         45296.334028
# 196       Sirene_Ativa 2024-01-05 09:29:53.000         45296.395752
# 197       Sirene_Ativa 2024-01-05 09:34:54.000         45296.399236
#
#                 End time             Duration      Event template  \
# 0    2024-01-10 13:25:00  1900-01-01 03:25:00  Parada_Equipamento
# ...

# %%
teste = df["Primary element"].value_counts()

# %%
teste
# Out:
# Primary element
# Dados                                 21
# 744A0590.ST                           19
# Alvura D1                             17
# Tanque Eq LVB > 50%                   13
# 782A0390.ME                           11
# 763A0550.ST                           10
# Alvura Deslig                         10
# G2                                    10
# Cond Lagoa de Contenção GB486pH256     8
# 744A0592.ST                            7
# Peroxido                               7
# Caustificação G1 - L1                  7
# Esvaziamento APP                       5
# Forno de Cal 2                         4
# GB463CLS_475_2.PV                      4
# 744A0595.ST                            3
# ETE                                    3
# GB452CL2SA_094.PV                      3
# Alvura Final G1                        3
# 744A0598.ST                            3
# Turbidez ETA                           2
# GB382A065                              2
# ...

# %%
teste.to_csv("teste.csv",encoding="utf-8-sig")
