# %%
import pandas as pd

# %%
from random import randrange, uniform
print(randrange(0, 9)) #faixa de inteiro
print(45*uniform(0, 9)) #faixa de ponto flutuante
# Out:
# 4
# 404.88166514624515

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ersantos\\Desktop\\Desktop\\Python\\trabalho'

# %%
df = pd.read_excel("bd.xlsx")

# %%
df.set_index('Data')
# Out:
#                      MATERIAL PARTICULADO  OPACIDADE CHAMINÉ  QUEIMA DE LICOR  \
# Data
# 2023-01-01 00:00:00             40.722862          25.505484      6783.482422
# 2023-01-01 00:01:00             39.740643          26.137339      6799.824219
# 2023-01-01 00:02:00             40.541351          26.479095      6810.753906
# 2023-01-01 00:03:00             42.685310          27.730089      6827.468262
# 2023-01-01 00:04:00             39.199699          25.035765      6812.541504
# ...                                   ...                ...              ...
# 2023-07-30 23:56:00             39.249111          27.455093      7028.434570
# 2023-07-30 23:57:00             40.748680          27.835001      7018.136719
# 2023-07-30 23:58:00             41.337421          29.070099      7025.130859
# 2023-07-30 23:59:00             40.444553          27.658560      7026.678223
# 2023-07-31 00:00:00             39.479019          28.211731      7021.125977
#
# ...

# %%
from pandasai import PandasAI

# %%
# Instantiate a LLM
from pandasai.llm.openai import OpenAI
llm = OpenAI(api_token="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")
pandas_ai = PandasAI(llm)

# %%
pandas_ai(df, prompt="Passe o número de vezes que o MATERIAL PARTICULADO passou de 40 em cada mes")
# Out:
# Month
# 1    11175
# 2    17226
# 3    15073
# 4    15980
# 5    27277
# 6    28076
# 7    32751
# dtype: int64

# %%
pandas_ai(df, prompt="Qual o maior número de MATERIAL PARTICULADO?")
# Out:
# 243.76597595214844

# %%
pandas_ai(df, prompt="Quando foi o maior pico de MATERIAL PARTICULADO?")
# Out:
# 'O maior pico de MATERIAL PARTICULADO ocorreu em: 2023-02-01 23:04:00'

# %%
pandas_ai(df, prompt="Passe a média de MATERIAL PARTICULADO de cada mes")
# Out:
# Month
# 1    37.726888
# 2    39.922135
# 3    38.398138
# 4    38.475574
# 5    34.640154
# 6    40.463924
# 7    43.131089
# Name: MATERIAL PARTICULADO, dtype: float64

# %%
pandas_ai(df, prompt="Gere um gráfico de tendência MATERIAL PARTICULADO para o mes de julho")

# %%
pandas_ai(df, prompt="Qual a temperatura média TEMP. LICOR nos primeiros 7 dias de julho 23 por dia. Arredondar com duas casas decimais. Montar um gráfico de barras com a cor verde")
