[
    "F1DPVD8U61v9dUme4BfqXXiDLQ8IwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19NUzFfTUFYSU1PX0cxLlBW",
    "F1DPVD8U61v9dUme4BfqXXiDLQ8YwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19NUzFfTUVESUFfRzEuUFY",
    "F1DPVD8U61v9dUme4BfqXXiDLQ3owCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19NUzFfVE9QXzEwX0RFU0NfRzEuUFY",
    "F1DPVD8U61v9dUme4BfqXXiDLQ34wCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19NUzFfVE9QXzEwX05PTUVfRzEuUFY",
    "F1DPVD8U61v9dUme4BfqXXiDLQ4IwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19NUzFfVE9QXzEwX1ZBTF9HMS5QVg"]
webIDs_energia = [
    "F1DPVD8U61v9dUme4BfqXXiDLQ6owCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19FTkVSR0lBX01BWElNT19HMS5QVg",
    "F1DPVD8U61v9dUme4BfqXXiDLQ64wCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19FTkVSR0lBX01FRElBX0cxLlBW",
    "F1DPVD8U61v9dUme4BfqXXiDLQ1YwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19FTkVSR0lBX1RPUF8xMF9ERVNDX0cxLlBW",
    "F1DPVD8U61v9dUme4BfqXXiDLQ1owCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19FTkVSR0lBX1RPUF8xMF9OT01FX0cxLlBW",
    "F1DPVD8U61v9dUme4BfqXXiDLQ14wCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19FTkVSR0lBX1RPUF8xMF9WQUxfRzEuUFY"]
webIDs = [webIDs_dig, webIDs_branq, webIDs_cr, webIDs_caust, webIDs_cf, webIDs_ete, webIDs_pq, webIDs_secagem,webIDs_energia]

# %%
df_dig = pd.read_excel("./DIG.xls")
df_branq = pd.read_excel("./BRANQ.xls")
df_cr = pd.read_excel("./CR.xls")
df_caust = pd.read_excel("./CAUST.xls")
df_cf = pd.read_excel("./CF.xls")
df_ete = pd.read_excel("./ETE.xls")
df_pq = pd.read_excel("./PQ.xls")
df_secagem = pd.read_excel("./SEC.xls")
df_energia = pd.read_excel("./ENERGIA.xls")
df_geral = [df_dig, df_branq, df_cr, df_caust, df_cf, df_ete, df_pq, df_secagem, df_energia]
# Out:
# WARNING *** file size (70563) not 512 + multiple of sector size (512)

# %%
i = 0
for df in df_geral:
    media = (df["# of ALARMS"].sum())/(7*24)
    maximo = round(media * randrange(1, 10))
    j = 0
    k = 0
    l = 0
    
    ## MÉDIA ##
    url = "https://svmgbpiwebapp.cmpcrs.com.br/piwebapi/streams/" + webIDs[i][1] +"/recorded"
    payload = [
        {
            "Timestamp": "t",
            "Value": int(media)
        }
    ]
    payload = str(payload)
    headers = {
      'X-Requested-With': 'XMLHttpRequest',
      'Content-Type': 'Application/json',
      'Authorization': 'Basic Y21wY3JzXGNzX3Bpd2ViOiNKVENaN0NrbjE='
    }
    response = requests.request("POST", url, headers=headers, data=payload,verify=False)
    
    ## MÁXIMO ##
    url = "https://svmgbpiwebapp.cmpcrs.com.br/piwebapi/streams/" + webIDs[i][0] +"/recorded"
    payload = [
        {
            "Timestamp": "t",
            "Value": int(maximo)
        }
    ]
    payload = str(payload)
    headers = {
      'X-Requested-With': 'XMLHttpRequest',
      'Content-Type': 'Application/json',
      'Authorization': 'Basic Y21wY3JzXGNzX3Bpd2ViOiNKVENaN0NrbjE='
    }
    response = requests.request("POST", url, headers=headers, data=payload,verify=False)
    
    ## DESCRIÇÃO ##
    j = 0
    for descricao in df.DESCRIPTION[:10]:
        url = "https://svmgbpiwebapp.cmpcrs.com.br/piwebapi/streams/" + webIDs[i][2] +"/recorded"
        payload = [
            {
                "Timestamp": "t+"+str(j)+"h",
                "Value": str(descricao)
            }
        ]
        payload = str(payload)
        headers = {
          'X-Requested-With': 'XMLHttpRequest',
          'Content-Type': 'Application/json',
          'Authorization': 'Basic Y21wY3JzXGNzX3Bpd2ViOiNKVENaN0NrbjE='
        }
        response = requests.request("POST", url, headers=headers, data=payload,verify=False)
        j = j + 1
    
    ## NOME ##
    j = 0
    for tag in df.BLOCK[:10]:
        url = "https://svmgbpiwebapp.cmpcrs.com.br/piwebapi/streams/" + webIDs[i][3] +"/recorded"
        payload = [
            {
                "Timestamp": "t+"+str(j)+"h",
                "Value": str(tag)
            }
        ]
        payload = str(payload)
        headers = {
          'X-Requested-With': 'XMLHttpRequest',
          'Content-Type': 'Application/json',
          'Authorization': 'Basic Y21wY3JzXGNzX3Bpd2ViOiNKVENaN0NrbjE='
        }
        response = requests.request("POST", url, headers=headers, data=payload,verify=False)
        j = j + 1
        
    ## VALOR ##
    j = 0
    for valor in df["# of ALARMS"][:10]:
        url = "https://svmgbpiwebapp.cmpcrs.com.br/piwebapi/streams/" + webIDs[i][4] +"/recorded"
        payload = [
            {
                "Timestamp": "t+"+str(j)+"h",
                "Value": int(valor)
            }
        ]   
        payload = str(payload)
        headers = {
          'X-Requested-With': 'XMLHttpRequest',
          'Content-Type': 'Application/json',
          'Authorization': 'Basic Y21wY3JzXGNzX3Bpd2ViOiNKVENaN0NrbjE='
        }
        response = requests.request("POST", url, headers=headers, data=payload,verify=False)
        j = j + 1
    i = i + 1
# Out:
# 29.452380952380953
# 206
# LAGOA DE CONTENCAO
# AR DE AGIT DECLORADOR 451-21-224
# BBA. POCO SATURACAO S931-02-25
# DRENO RESIDUOS TQ PRE-CAMADA 144
# TEMPERATURA DIFERENCIAL
# TEMP. SAIDA AGUA  GELADA
# TEMPERATURA DIFERENCIAL
# TQ. ESTOC# NACLO3
# UNID. DE REFRIG#
# SALMOURA ENT. 451-28-615/616
# 486TI_258
# 451FI_027
# 451_34_108FB
# 451HSV_732
# 451DTI_193
# 454TIA_126
# 451DTI_193
# 453LI_010
# 451PIC_261
# 451FI_327
# 1646
# 112
# 104
# 87
# 82
# 82
# 68
# 68
# 57
# 53
