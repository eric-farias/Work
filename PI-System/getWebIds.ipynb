# %%
import requests
import json

# %%
def get_web_id(tag):
    url = f"https://svmgbpiwebapp.cmpcrs.com.br/piwebapi/search/query?q=name:{tag}"

    payload = {}
    headers = {
      'Authorization': 'Basic Y21wY3JzXGNzX3Bpd2ViOiNKVENaN0NrbjE='
    }

    response = requests.request("GET", url, headers=headers, data=payload,verify=False)

    return response.text

# %%
tag_list = [
    "AF_ALARMES_BRANQ_MEDIA_DIA.PV",
    "AF_ALARMES_CAUSTIFICACA_MEDIA_DIA.PV",
    "AF_ALARMES_COZIMENTO_MEDIA_DIA.PV",
    "AF_ALARMES_CR2_MEDIA_DIA.PV",
    "AF_ALARMES_ENERGIA_MEDIA_DIA.PV",
    "AF_ALARMES_ETA_ETE_MEDIA_DIA.PV",
    "AF_ALARMES_ETAC_MEDIA_DIA.PV",
    "AF_ALARMES_MS2_MS3_MEDIA_DIA.PV",
    "AF_ALARMES_PATIO_MEDIA_DIA.PV",
    "AF_ALARMES_PLANTA_QUIM_MEDIA_DIA.PV",
    "AF_ALARMES_BRANQ_MAXIMO_DIA.PV",
    "AF_ALARMES_CAUSTIFICACA_MAXIMO_DIA.PV",
    "AF_ALARMES_COZIMENTO_MAXIMO_DIA.PV",
    "AF_ALARMES_CR2_MAXIMO_DIA.PV",
    "AF_ALARMES_ENERGIA_MAXIMO_DIA.PV",
    "AF_ALARMES_ETA_ETE_MAXIMO_DIA.PV",
    "AF_ALARMES_ETAC_MAXIMO_DIA.PV",
    "AF_ALARMES_MS2_MS3_MAXIMO_DIA.PV",
    "AF_ALARMES_PATIO_MAXIMO_DIA.PV",
    "AF_ALARMES_PLANTA_QUIM_MAXIMO_DIA.PV",
    "AF_ALARMES_BRANQ_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_BRANQ_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_BRANQ_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_CAUSTIFICACA_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_CAUSTIFICACA_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_CAUSTIFICACA_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_COZIMENTO_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_COZIMENTO_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_COZIMENTO_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_CR2_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_CR2_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_CR2_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_ENERGIA_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_ENERGIA_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_ENERGIA_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_ETA_ETE_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_ETA_ETE_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_ETA_ETE_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_ETAC_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_ETAC_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_ETAC_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_MS2_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_MS2_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_MS2_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_PATIO_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_PATIO_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_PATIO_TOP_10_VAL_DIA.PV",
    "AF_ALARMES_PLANTA_QUIM_TOP_10_DESC_DIA.PV",
    "AF_ALARMES_PLANTA_QUIM_TOP_10_NOME_DIA.PV",
    "AF_ALARMES_PLANTA_QUIM_TOP_10_VAL_DIA.PV"
]

web_ids =[]

# %%
for tag in tag_list:
    teste = json.loads(get_web_id(tag))
    web_ids.append(teste["Items"][0]["WebId"])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'svmgbpiwebapp.cmpcrs.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'svmgbpiwebapp.cmpcrs.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'svmgbpiwebapp.cmpcrs.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
web_ids
# Out:
# ['F1DPVD8U61v9dUme4BfqXXiDLQPbwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19CUkFOUV9NRURJQV9ESUEuUFY',
#  'F1DPVD8U61v9dUme4BfqXXiDLQPrwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19DQVVTVElGSUNBQ0FfTUVESUFfRElBLlBW',
#  'F1DPVD8U61v9dUme4BfqXXiDLQP7wCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19DT1pJTUVOVE9fTUVESUFfRElBLlBW',
#  'F1DPVD8U61v9dUme4BfqXXiDLQQLwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19DUjJfTUVESUFfRElBLlBW',
#  'F1DPVD8U61v9dUme4BfqXXiDLQQbwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19FTkVSR0lBX01FRElBX0RJQS5QVg',
#  'F1DPVD8U61v9dUme4BfqXXiDLQQrwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19FVEFfRVRFX01FRElBX0RJQS5QVg',
#  'F1DPVD8U61v9dUme4BfqXXiDLQQ7wCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19FVEFDX01FRElBX0RJQS5QVg',
#  'F1DPVD8U61v9dUme4BfqXXiDLQRLwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19NUzJfTVMzX01FRElBX0RJQS5QVg',
#  'F1DPVD8U61v9dUme4BfqXXiDLQRbwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19QQVRJT19NRURJQV9ESUEuUFY',
#  'F1DPVD8U61v9dUme4BfqXXiDLQRrwCAAU1ZHQlBJMDFcQUZfQUxBUk1FU19QTEFOVEFfUVVJTV9NRURJQV9ESUEuUFY',
# ...
